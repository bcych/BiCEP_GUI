# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#This cell converts your data from MagIC format to the internal BiCEP
#format. It only needs to be run once. Note that when first running,
#importing BiCEP will take a few minutes to compile the stan models.
from BiCEP.conversion import generate_arai_plot_table

#Use wd to specify a working directory where all your files are kept.
generate_arai_plot_table('example',wd='example_magic_files/')
# Out:
# Data conversion finished- check thellier_convert.log for errors

# %%
#This cell imports the necessary libraries to run the GUI
import matplotlib.pyplot as plt
# %matplotlib widget
from BiCEP.gui import GUI
GUI()
